# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px 
import seaborn as sns
df = pd.read_csv("songs_normalize.csv")

# %%
df
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
df.groupby('year')["popularity","loudness"].mean().sort_values(by = "year")
# Out:
# <ipython-input-16-f7259a2475de>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('year')["popularity","loudness"].mean().sort_values(by = "year")
#       popularity   loudness
# year
# 1998   49.000000 -11.241000
# 1999   64.921053  -5.936816
# 2000   58.554054  -6.201378
# 2001   59.407407  -5.879213
# 2002   62.400000  -5.471333
# 2003   58.793814  -5.797021
# 2004   58.427083  -5.233708
# 2005   61.759615  -5.928894
# 2006   57.389474  -5.673337
# 2007   59.925532  -4.994904
# 2008   63.721649  -5.183258
# 2009   61.535714  -4.979786
# 2010   60.747664  -4.862458
# 2011   58.565657  -5.163778
# 2012   60.556522  -4.827043
# 2013   54.786517  -5.802056
# 2014   59.384615  -5.431413
# 2015   57.747475  -5.648000
# 2016   54.171717  -5.878212
# 2017   53.882883  -5.561847
# 2018   70.850467  -5.863206
# 2019   63.011236  -5.869416
# 2020   43.333333  -4.925333

# %%
# df['artist'].value_counts()
# df['year'].value_counts()
df['genre'].value_counts()
# Out:
# pop                                      428
# hip hop, pop                             277
# hip hop, pop, R&B                        244
# pop, Dance/Electronic                    221
# pop, R&B                                 178
# hip hop                                  124
# hip hop, pop, Dance/Electronic            78
# rock                                      58
# rock, pop                                 43
# Dance/Electronic                          41
# rock, metal                               38
# pop, latin                                28
# pop, rock                                 26
# set()                                     22
# hip hop, Dance/Electronic                 16
# latin                                     15
# pop, rock, metal                          14
# hip hop, pop, latin                       14
# pop, rock, Dance/Electronic               13
# R&B                                       13
# country                                   10
# ...

# %%
len(df["genre"].unique())
# Out:
# 59

# %%
plt.figure(figsize = (15,8))
plt.xticks(rotation = 90) # rotate x values
sns.countplot(x= "genre", data = df)
# Out:
# <AxesSubplot:xlabel='genre', ylabel='count'>

# %%
fig = px.histogram(df, x='genre', title = 'Distribution of Genre')
fig.update_xaxes(categoryorder = "total ascending")
fig.update_xaxes(tickangle = -90)
fig.show()
# Out:
# <div>                            <div id="a0e1b20a-8bfb-4cdb-82fe-ca87ed38225a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0e1b20a-8bfb-4cdb-82fe-ca87ed38225a")) {                    Plotly.newPlot(                        "a0e1b20a-8bfb-4cdb-82fe-ca87ed38225a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"genre=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":["pop","rock, pop","pop, country","rock, metal","pop","hip hop, pop, R&B","hip hop","pop, rock","pop, R&B","Dance/Electronic","pop","pop","pop","rock, pop","pop, Dance/Electronic","hip hop, pop, R&B","pop","pop","
# ...

# %%
# good for quantitative data 
plt.figure(figsize = (15,8))
# sns.histplot(df["danceability"], binwidth = 0.05)
#sns.histplot(df["danceability"], bins = 30)
sns.histplot(df["danceability"], bins = 30, kde = True, stat = "density") # kernel density estimate, stat = density make y axis
# scale better
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='Count'>

# %%
fig = px.histogram(df, x = "danceability", title = "distribution of dance ability", nbins = 30)
fig.update_layout(bargap= 0.1)
fig.show()
# Out:
# <div>                            <div id="186504ae-b80b-4799-a90b-ee8550bc1ff0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("186504ae-b80b-4799-a90b-ee8550bc1ff0")) {                    Plotly.newPlot(                        "186504ae-b80b-4799-a90b-ee8550bc1ff0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"danceability=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":30,"offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[0.7509999999999999,0.434,0.529,0.551,0.614,0.706,0.9490000000000001,0.708,0.713,0.72,0.617,0.745,0.8220000000000001,0.586,0.6890000000000001,0.797,0.7609999999999999,0.6709999999999999,0.74,0.9
# ...
